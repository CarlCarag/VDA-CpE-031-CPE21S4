# %% [markdown]
# <a href="https://colab.research.google.com/github/CarlCarag/VDA-CpE-031-CPE21S4/blob/main/Exercise_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy

# %%
# !pip install pandas

# %%
# !pip install matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#Generate Data
x = np.array([1,2,3,4,5])
y = np.array([2,4,5,4,5])

#Calculate the predicted values of y using the regression line equation
y_pred = slope * x + intercept

#Calculate the slope and y-intercept of the regression line
slope, intercept = np.polyfit(x, y, 1)

plt.scatter(x, y)
plt.plot(x, y_pred, color='red')
plt.title('Regression Line')
plt.grid(True)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#Generate Data
x = np.array([60,90,70,85,80,65,75,60,75,70])
y = np.array([70,95,70,75,90,75,75,60,80,65])

# %%
#Calculate the predicted values of y using the regression line equation
y_pred = slope * x + intercept

# %%
#Calculate the slope and y-intercept of the regression line
slope, intercept = np.polyfit(x, y, 1)

# %%
plt.scatter(x, y)
plt.plot(x, y_pred, color='red')
plt.title('Regression Line')
plt.grid(True)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# Interpretation:
# This graph has 2 data sets that shows a strong positive correlation
# with a correlation of r = 0.7879

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-2,2,100)
y= x**2

fig = plt.figure(figsize=(10,5))
plt.plot (x,y)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
