# %% [markdown]
# <a href="https://colab.research.google.com/github/CarlCarag/VDA-CpE-031-CPE21S4/blob/main/Exercise_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Installing Pandas
# !pip install pandas

# %%
#Loading CSV file in the colab
from google.colab import files
uploaded = files.upload()

import pandas as pd
data = pd.read_csv('Data1.csv')
purchases = pd.DataFrame(data)
(purchases)
# Out:
#      <input type="file" id="files-ea1493ec-5060-4bd3-80ef-b2796bfd6c17" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ea1493ec-5060-4bd3-80ef-b2796bfd6c17">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Creating a dataframe from a dictionary of lists
import pandas as pd

player = { 'Rank': [1,2,3,4,5], 'Athlete' : ['Cristiano Ronaldo','Jon Rahm','Lionel Messi','LeBron James','Kylian Mbappé'], 'Sports':['Soccer','Golf','Soccer','Basketball','Soccer'], 'Nationality':['Portuguese', 'Spanish','Argentine', 'American','French'], 'Salary': ['$215M','$181M','$65M','$45.7M','$100M']}
playerdata = pd.DataFrame(player)

playerdata = pd.DataFrame(player)

(playerdata)
# Out:
#    Rank            Athlete      Sports Nationality  Salary
# 0     1  Cristiano Ronaldo      Soccer  Portuguese   $215M
# 1     2           Jon Rahm        Golf     Spanish   $181M
# 2     3       Lionel Messi      Soccer   Argentine    $65M
# 3     4       LeBron James  Basketball    American  $45.7M
# 4     5      Kylian Mbappé      Soccer      French   $100M

# %%
#Creating a dataframe from a list of dictionaries
import pandas as pd

player = [
    {'Rank': 1, 'Athlete': 'Cristiano Ronaldo', 'Sports': 'Soccer', 'Nationality': 'Portuguese', 'Salary': '$215M'},
    {'Rank': 2, 'Athlete': 'Jon Rahm', 'Sports': 'Golf', 'Nationality': 'Spanish', 'Salary': '$181M'},
    {'Rank': 3, 'Athlete': 'Lionel Messi', 'Sports': 'Soccer', 'Nationality': 'Argentine', 'Salary': '$65M'},
    {'Rank': 4, 'Athlete': 'LeBron James', 'Sports': 'Basketball', 'Nationality': 'American', 'Salary': '$45.7M'},
    {'Rank': 5, 'Athlete': 'Kylian Mbappé', 'Sports': 'Soccer', 'Nationality': 'French', 'Salary': '$100M'}
]
playerdata = pd.DataFrame(player)

(playerdata)
# Out:
#    Rank            Athlete      Sports Nationality  Salary
# 0     1  Cristiano Ronaldo      Soccer  Portuguese   $215M
# 1     2           Jon Rahm        Golf     Spanish   $181M
# 2     3       Lionel Messi      Soccer   Argentine    $65M
# 3     4       LeBron James  Basketball    American  $45.7M
# 4     5      Kylian Mbappé      Soccer      French   $100M

# %%
#Selecting single dataframe columns

playerdata['Rank']
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: Rank, dtype: int64

# %%
#Selecting data frame multiple columns
playerdata[['Rank','Athlete','Nationality']]
# Out:
#    Rank            Athlete Nationality
# 0     1  Cristiano Ronaldo  Portuguese
# 1     2           Jon Rahm     Spanish
# 2     3       Lionel Messi   Argentine
# 3     4       LeBron James    American
# 4     5      Kylian Mbappé      French

# %%
#Selecting single dataframe rows
playerdata.iloc[0]
# Out:
# Rank                           1
# Athlete        Cristiano Ronaldo
# Sports                    Soccer
# Nationality           Portuguese
# Salary                     $215M
# Name: 0, dtype: object

# %%
#Selecting multiple dataframe rows
playerdata.iloc[0:3]
# Out:
#    Rank            Athlete  Sports Nationality Salary
# 0     1  Cristiano Ronaldo  Soccer  Portuguese  $215M
# 1     2           Jon Rahm    Golf     Spanish  $181M
# 2     3       Lionel Messi  Soccer   Argentine   $65M
